# %% [markdown]
# # Load "four priors" datasets
#
# author: steeve laquitaine
#
# purpose: load the dataset for the experiment with four priors ("experiment 01")

# %% [markdown]
# ## Setup

# %% [markdown]
# Setup virtual environment:
#
# ```bash
# python -m venv my_env
# source my_env/bin/activate
# pip install pandas ipykernel
# ````

# %%
# setup dependencies
import pandas as pd

proj_path = "/Users/laquitai/Desktop/projects/project/projInference"
os.chdir(proj_path)

# %%
# load dataset
data = pd.read_csv("data/csv/data01_direction4priors.csv")

# %%
# preview
data.head()
# Out:
#    trial_index  trial_time  response_arrow_start_angle  motion_direction  \
# 0            1    0.000000                         NaN               225
# 1            2    2.730730                         NaN               225
# 2            3    4.913950                         NaN               235
# 3            4    6.997296                         NaN               225
# 4            5    9.097130                         NaN               215
#
#    motion_coherence  estimate_x  estimate_y  reaction_time  raw_response_time  \
# 0              0.12   -1.749685   -1.785666            NaN                NaN
# 1              0.12   -1.819693   -1.714269            NaN                NaN
# 2              0.06   -1.562674   -1.951422            NaN                NaN
# 3              0.06   -1.601388   -1.919781            NaN                NaN
# 4              0.24   -1.639461   -1.887371            NaN                NaN
#
#    prior_std  prior_mean  subject_id          experiment_name  experiment_id  \
# 0         10         225           1  data01_direction4priors             11
# 1         10         225           1  data01_direction4priors             11
# 2         10         225           1  data01_direction4priors             11
# 3         10         225           1  data01_direction4priors             11
# 4         10         225           1  data01_direction4priors             11
#
#    session_id  run_id
# 0           1       1
# 1           1       1
# 2           1       1
# 3           1       1
# 4           1       1

# %%
# get total number of trials in dataset
data.shape
# Out:
# (83213, 16)

# %%
# get dataset from subject 1
data[data["subject_id"]==1]
# Out:
#       trial_index  trial_time  response_arrow_start_angle  motion_direction  \
# 0               1    0.000000                         NaN               225
# 1               2    2.730730                         NaN               225
# 2               3    4.913950                         NaN               235
# 3               4    6.997296                         NaN               225
# 4               5    9.097130                         NaN               215
# ...           ...         ...                         ...               ...
# 8557          222  664.439911                       211.0               275
# 8558          223  667.604452                        78.0               305
# 8559          224  671.238262                       261.0               205
# 8560          225  673.514350                       182.0               285
# 8561          226  676.199692                       119.0                45
#
#       motion_coherence  estimate_x  estimate_y  reaction_time  \
# 0                 0.12   -1.749685   -1.785666            NaN
# 1                 0.12   -1.819693   -1.714269            NaN
# 2                 0.06   -1.562674   -1.951422            NaN
# 3                 0.06   -1.601388   -1.919781            NaN
# 4                 0.24   -1.639461   -1.887371            NaN
# ...                ...         ...         ...            ...
# 8557              0.12    0.805510   -2.366676       1.643590
# 8558              0.24    1.342272   -2.109101       2.110994
# 8559              0.24   -2.249465   -1.090829       0.749414
# 8560              0.12    1.289436   -2.141811       1.161366
# 8561              0.06    0.140061    2.496074       1.507863
#
#       raw_response_time  prior_std  prior_mean  subject_id  \
# 0                   NaN         10         225           1
# 1                   NaN         10         225           1
# 2                   NaN         10         225           1
# 3                   NaN         10         225           1
# 4                   NaN         10         225           1
# ...                 ...        ...         ...         ...
# 8557         667.380119         80         225           1
# 8558         671.012085         80         225           1
# 8559         673.284190         80         225           1
# 8560         675.972228         80         225           1
# 8561         679.004105         80         225           1
#
#               experiment_name  experiment_id  session_id  run_id
# 0     data01_direction4priors             11           1       1
# 1     data01_direction4priors             11           1       1
# 2     data01_direction4priors             11           1       1
# 3     data01_direction4priors             11           1       1
# 4     data01_direction4priors             11           1       1
# ...                       ...            ...         ...     ...
# 8557  data01_direction4priors             12           8      40
# 8558  data01_direction4priors             12           8      40
# 8559  data01_direction4priors             12           8      40
# 8560  data01_direction4priors             12           8      40
# 8561  data01_direction4priors             12           8      40
#
# [8562 rows x 16 columns]

# %%
SUBJECT_ID = 12
RUN_ID = 30

data[(data["subject_id"]==SUBJECT_ID) & (data["run_id"]==RUN_ID)]
# Out:
#        trial_index  trial_time  response_arrow_start_angle  motion_direction  \
# 83011            1    0.000000                       344.0               185
# 83012            2    2.962175                       168.0               275
# 83013            3    6.164732                        31.0               295
# 83014            4    9.306475                        93.0               225
# 83015            5   12.208410                       283.0               255
# ...            ...         ...                         ...               ...
# 83208          198  571.895796                        47.0               205
# 83209          199  574.708207                       238.0               265
# 83210          200  577.408906                       300.0               245
# 83211          201  579.720922                        10.0               185
# 83212          202  582.602137                        33.0               185
#
#        motion_coherence  estimate_x  estimate_y  reaction_time  \
# 83011              0.06   -1.898931   -1.626057       1.421743
# 83012              0.12    0.362629   -2.473560       1.689632
# 83013              0.06    0.094101   -2.498228       1.630747
# 83014              0.24   -2.367233   -0.803872       1.385897
# 83015              0.12   -0.803734   -2.367280       1.194757
# ...                 ...         ...         ...            ...
# 83208              0.06   -0.895369   -2.334162       1.298565
# 83209              0.12   -1.915175   -1.606893       1.175129
# 83210              0.06   -0.076489   -2.498830       0.793728
# 83211              0.12    0.177676   -2.493678       1.363531
# 83212              0.06   -1.507874   -1.994070       1.553555
#
#        raw_response_time  prior_std  prior_mean  subject_id  \
# 83011           2.732049         40         225          12
# 83012           5.941724         40         225          12
# 83013           9.084760         40         225          12
# 83014          11.981728         40         225          12
# 83015          14.692875         40         225          12
# ...                  ...        ...         ...         ...
# 83208         574.493754         40         225          12
# 83209         577.181812         40         225          12
# 83210         579.492137         40         225          12
# 83211         582.373810         40         225          12
# 83212         585.445742         40         225          12
#
#                experiment_name  experiment_id  session_id  run_id
# 83011  data01_direction4priors             12           6      30
# 83012  data01_direction4priors             12           6      30
# 83013  data01_direction4priors             12           6      30
# 83014  data01_direction4priors             12           6      30
# 83015  data01_direction4priors             12           6      30
# ...                        ...            ...         ...     ...
# 83208  data01_direction4priors             12           6      30
# 83209  data01_direction4priors             12           6      30
# 83210  data01_direction4priors             12           6      30
# 83211  data01_direction4priors             12           6      30
# 83212  data01_direction4priors             12           6      30
#
# [202 rows x 16 columns]
